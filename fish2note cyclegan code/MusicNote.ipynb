# %% [markdown]
# ## Music notes detection, crop and sheet of music score

# %%
import cv2
import os
import numpy as np

def threshold(image):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    ret, image = cv2.threshold(image, 127, 255, cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)
    return image

def remove_noise(image):
    image = threshold(image) # 이미지 이진화
    mask = np.zeros(image.shape, np.uint8) # 보표 영역만 추출하기 위해 마스크 생성
    cnt, labels, stats, centroids = cv2.connectedComponentsWithStats(image) # 레이블링
    for i in range(1, cnt):
        x, y, w, h, area = stats[i]
        if w > image.shape[1] * 0.5: # 보표 영역에만
            cv2.rectangle(mask, (x,y,w,h), (255,0,0),-1) # 사각형 그리기
    masked_image = cv2.bitwise_and(image,mask)
    return masked_image

def remove_staves(image):
    height, width = image.shape
    staves = [] #오선의 좌표들이 저장될 리스트

    for row in range(height):
        pixels = 0
        for col in range(width):
            pixels += (image[row][col] == 255) # 한 행에 존재하는 흰색 픽셀의 개수를 셈
        if pixels >= width * 0.5: # 이미지 넓이의 50% 이상이라면
            if len(staves) == 0 or abs(staves[-1][0] + staves[-1][1] - row) > 1: # 첫 오선이거나 이전에 검출된 오선과 다른 오선
                staves.append([row, 0]) # 오선 추가 [오선의 y좌표][오선 높이]
            else: # 이전에 검출된 오선과 다른 오선
                staves[-1][1] += 1 # 높이 업데이트

    for staff in range(len(staves)):
        top_pixel = staves[staff][0] # 오선의 최상단 y좌표
        bot_pixel = staves[staff][0] + staves[staff][1] # 오선의 최하단 y 좌표 (오선의 최상단 y좌표 + 오선 높이)
        for col in range(width):
            if image[top_pixel -1][col] == 0 and image[bot_pixel + 1][col] == 0: # 오선 위, 아래로 픽셀이 있는지 타색
                for row in range(top_pixel, bot_pixel + 1):
                    image[row][col] = 0
    return image, [x[0] for x in staves]

def normalization(image, staves, standard):
    avg_distance = 0
    lines = int(len(staves) / 5) #보표의 개수
    for line in range(lines):
        for staff in range(4):
            staff_above = staves[line * 5 + staff]
            staff_below = staves[line * 5 + staff + 1]
            avg_distance += abs(staff_above - staff_below) # 오선의 간격을 누적해서 더해줌
    avg_distance /= len(staves) - lines # 오선 간의 평균 간격
    height, width = image.shape # 이미지의 높이와 넓이
    weight = standard / avg_distance # 기준으로 정한 오선 간격을 이용해 가중치를 구함
    new_width = int(width * weight) # 이미지의 넓이에 가중치를 곱해줌
    new_height = int(height * weight) # 이미지의 높이에 가중치를 곱해줌

    image = cv2.resize(image, (new_width, new_height)) # 이미지 리사이징
    ret, image = cv2.threshold(image, 127, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU) # 이미지 이진화
    staves = [x * weight for x in staves] # 오선 좌표에도 가중치를 곱해줌
    return image, staves

def weighted(value):
    standard = 10
    return int(value * (standard / 10))

def closing(image):
    kernel = np.ones((weighted(5), weighted(5)), np.uint8)
    image = cv2.morphologyEx(image, cv2.MORPH_CLOSE, kernel)
    return image

def put_text(image, text, loc):
    font = cv2.FONT_HERSHEY_SIMPLEX
    cv2.putText(image, str(text), loc, font, 0.6, (255,0,0), 2)

def get_center(y, h):
    return (y+y+h) / 2


def object_detection(image, staves):
    lines = int(len(staves) / 5) #보표의 개수
    objects = [] # 구성요소 정보가 저장될 리스트

    closing_image = closing(image)
    cnt, labels, stats, centroids = cv2.connectedComponentsWithStats(closing_image) # 모든 객체 검출
    for i in range(1, cnt):
        (x, y, w, h, area) = stats[i]
        if w >= weighted(5) and h >= weighted(5): # 악보의 구성요소가 되기 위한 넓이, 높이 조건
            center = get_center(y, h)
            #cv2.rectangle(image, (x,y,w,h),(255,0,0),1)
            box = (x,y,w,h)
            crop = image[y-1:y+h+1, x-1:x+w+1]
            title = '/content/dataset/Note94_c{0}{1}{2}{3}.jpg'.format(x,y,w,h)
            crop = 255-crop
            cv2.imwrite(title,crop)
            for line in range(lines):
                area_top = staves[line*5] - weighted(20) # 위치 조건(상단)
                area_bot = staves[(line +1)*5 -1] + weighted(20) # 위치 조건 (하단)
                if area_top <= center <= area_bot:
                    objects.append([line, (x,y,w,h, area)]) # 객체 리스트에 보표 번호와 객체의 정보(위치, 크기)를 추가
    objects.sort() # 보표 번호 -> x 좌표 순으로 오름차순 정렬
    return image, objects 

VERTICAL = True 
HORIZONTAL = False 

def get_line(image, axis, axis_value, start, end, length):
    if axis:
        points = [(i, axis_value) for i in range(start, end)]
    else:
        points = [(axis_value, i) for i in range(start, end)]
    pixels = 0
    for i in range(len(points)):
        (y, x) = points[i]
        pixels += (image[y][x] == 255)
        next_point = image[y+1][x] if axis else image[y][x+1]
        if next_point == 0 or i == len(points) - 1:
            if pixels >= weighted(length):
                break
            else:
                pixles = 0
    return y if axis else x, pixels


def stem_detection(image, stats, length):
    (x, y, w, h, area) = stats
    stems = [] 
    for col in range(x, x+w):
        end, pixels = get_line(image, VERTICAL, col, y, y+h, length)
        if pixels:
            if len(stems) == 0 or abs(stems[-1][0] + stems[-1][2] - col) >= 1:
                (x, y, w, h) = col, end - pixels +1, 1, pixels
                stems.append([x,y,w,h])
            else:
                stems[-1][2] +=1 
    return stems

def object_analysis(image, objects):
    for obj in objects:
        stats = obj[1]
        stems = stem_detection(image, stats, 30)
        direction = None 
        if len(stems) > 0:
            if stems[0][0] - stats[0] >= weighted(5):
                direction = True 
            else:
                direction = False 
        obj.append(stems)
        obj.append(direction)
    return image, objects

def recognize_key(image, staves, stats):
    (x,y,w,h,area) = stats 
    ts_conditions = (
        staves[0] + weighted(5) >= y >= staves[0] - weighted(5) and 
        staves[4] + weighted(5) >= y+h >= staves[4] - weighted(5) and 
        staves[2] + weighted(5) >= get_center(y,h) >= staves[2] - weighted(5) and 
        weighted(18) >= w >= weighted(10) and 
        weighted(45) >= h >= weighted(35)
    )
    if ts_conditions:
        return True, 0
    else:
        stems = stem_detection(image, stats, 20)
        if stems[0][0] - x >= weighted(3):
            key = int(10 * len(stems) / 2)
        else: 
            key = 100 * len(stems)
    return False, key

def recognition(image, staves, objects):
    key = 0 
    time_signature = False 
    beats = [] # 박자 리스트
    pitches = [] #음이름 리스트

    for i in range(1, len(objects)):
        obj = objects[i]
        line = obj[0]
        stats = obj[1]
        stems = obj[2]
        direction = obj[3]
        (x,y,w,h,area) = stats 
        staff = staves[line * 5: (line+1)*5]
        if not time_signature: #조표가 완전히 탐색되지 않음
            ts, temp_key = recognize_key(image, staff, stats)
            time_signature = ts 
            key += temp_key 
        else: # 조표가 완전히 탐색되었음
            notes = recognize_note(image, staff, stats, stems, direction)
            if len(notes[0]):
                for beat in notes[0]:
                    beats.append(beat)
                for pitch in notes[1]:
                    pitches.append(pitch)
        cv2.rectangle(image, (x,y,w,h), (255,0,0), 1)
        put_text(image, i, (x,y-weighted(20)))
    return image, key, beats, pitches

def count_rect_pixels(image, rect):
    x,y,w,h = rect
    pixels = 0
    for row in range(y, y+h):
        for col in range(x, x+w):
            if image[row][col] == 255:
                pixels += 1
    return pixels


def recognize_note_head(image, stem, direction):
    (x, y, w, h) = stem
    if direction:
        area_top = y + h - weighted(7)
        area_bot = y + h + weighted(7)
        area_left = x - weighted(14)
        area_right = x
    else:
        area_top = y - weighted(7)
        area_bot = y + weighted(7)
        area_left = x + w
        area_right = x + w + weighted(14)
   
    cnt = 0
    cnt_max = 0
    head_center= 0
    pixel_cnt = count_rect_pixels(image, (area_left, area_top, area_right - area_left, area_bot-area_top))
    for row in range(area_top, area_bot):
        col, pixels = get_line(image, HORIZONTAL, row, area_left, area_right, 5)
        pixels += 1
        if pixels >= weighted(5):
            cnt+= 1
            cnt_max = max(cnt_max, pixels)
            head_center += row
    head_exist = (cnt >= 3 and pixel_cnt >= 50)
    head_fill = (cnt >= 8 and cnt_max >= 9 and pixel_cnt >= 80)
    head_center = head_center/cnt
    return head_exist, head_fill, head_center

def count_pixels_part(image, area_top, area_bot, area_col):
    cnt = 0
    flag = False
    for row in range(area_top, area_bot):
        if not flag and image[row][area_col] == 255:
            flag = True
            cnt+=1
        elif flag and image[row][area_col] == 0:
            flag = False
    return cnt


def recognize_note_tail(image, index, stem, direction):
    (x,y,w,h) = stem
    if direction:
        area_top = y
        area_bot = y+h-weighted(15)
    else: 
        area_top = y+weighted(15)
        area_bot = y+h
    if index:
        area_col = x - weighted(4)
    else: 
        area_col = x+w+weighted(4)
    cnt = count_pixels_part(image, area_top, area_bot, area_col)
    return cnt

def recognize_note_dot(image, stem, direction, tail_cnt, stems_cnt):
    (x,y,w,h) = stem
    if direction:
        area_top = y+h-weighted(10)
        area_bot = y+h+weighted(5)
        area_left = x+w+weighted(2)
        area_right = x+w+weighted(12)
    else:
        area_top = y-weighted(10)
        area_bot = y+weighted(5)
        area_left = x+w+weighted(14)
        area_right = x+w+weighted(24)
    dot_rect = (
        area_left, 
        area_top, 
        area_right - area_left,
        area_bot - area_top
    )
    pixels = count_rect_pixels(image, dot_rect)
    threshold = (10,15,20,30)
    if direction and stems_cnt == 1:
        return pixels >= weighted(threshold[tail_cnt])
    else:
        return pixels >= weighted(threshold[0])


def recognize_note(image, staff, stats, stems, direction):
    (x,y,w,h,area) = stats
    notes = []
    pitches = []
    note_condition = (
        len(stems) and 
        w >= weighted(10) and # 넓이 조건 
        h >= weighted(35) and # 높이 조건
        area >= weighted(95) # 픽셀 개수 조건
    )
    if note_condition:
        for i in range(len(stems)):
            stem = stems[i]
            head_exist, head_fill, head_center = recognize_note_head(image, stem, direction)
            if head_exist:
                tail_cnt = recognize_note_tail(image, i, stem, direction)
                dot_exist = recognize_note_dot(image, stem, direction, len(stems), tail_cnt )
                note_classification = (
                    ((not head_fill and tail_cnt ==0 and not dot_exist), 2),
                    ((not head_fill and tail_cnt ==0 and dot_exist), -2),
                    ((head_fill and tail_cnt ==0 and not dot_exist), 4),
                    ((head_fill and tail_cnt ==0 and dot_exist), -4),
                    ((head_fill and tail_cnt ==1 and not dot_exist), 8),
                    ((head_fill and tail_cnt ==1 and dot_exist), -8),
                    ((head_fill and tail_cnt ==2 and not dot_exist), 16),
                    ((head_fill and tail_cnt ==2 and dot_exist), -16),
                    ((head_fill and tail_cnt ==3 and not dot_exist), 32),
                    ((head_fill and tail_cnt ==3 and dot_exist), -32)
                )
                for j in range(len(note_classification)):
                    if note_classification[j][0]:
                        note = note_classification[j][1]
                        notes.append(note)
                        put_text(image, note, (stem[0]- weighted(10), stem[1]+stem[3]+weighted(30)))
                        break

    return notes, pitches






img = cv2. imread('Note22.png', cv2.IMREAD_COLOR)
# 1. 보표 영역 추출 및 그 외 노이즈 제거
image_1 = remove_noise(img)

# 2. 오선 제거
image_2, staves = remove_staves(image_1)

# 3. 악보 이미지 정규화
image_3, staves = normalization(image_2, staves, 10)

# 4. 객체 검출 과정
image_4, objects = object_detection(image_3, staves)

# 5. 객체 분석 과정
#image_5, objects = object_analysis(image_4, objects)

# 6. 인식 과정
#image_6, key, beats, pitches = recognition(image_5, staves, objects)

cv2.imwrite("remove22.png",image_4)
# Out:
# True

# %% [markdown]
# ## Add margin to image

# %%
from PIL import Image
  
image = Image.open("remove22.png")


right = 50
left = 50
top = 50
bottom = 50
  
width, height = image.size
  
new_width = width + right + left
new_height = height + top + bottom
  
result = Image.new("RGB", (new_width, new_height), (255, 255, 255))
  
result.paste(image, (left, top))
  
result.save('mNote_output2.png')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-3db03b76d8b1> in <module>
#       2
#       3 image = Image.open("remove22.png")
# ----> 4 image = 255 - image
#       5
#       6 right = 50
#
# TypeError: unsupported operand type(s) for -: 'int' and 'PngImageFile'

# %% [markdown]
# ## Add margin to multi-images

# %%
#%cd /content/pytorch-CycleGAN-and-pix2pix/datasets
# !unzip -qq "/content/dataset/nntrain.zip"

# %%
import os 
import numpy as np
from PIL import Image


#%cd /content/dataset/
image_path = '/content/nntrain/'
img_list = os.listdir(image_path)
img_list_jpg = [img for img in img_list if img.endswith(".jpg")] 
os.chdir('/content/nntrain/')
print(img_list[1])
for i in img_list_jpg:
    image = Image.open(i)
    right = 25
    left = 25
    top = 25
    bottom = 25

    width, height = image.size
    new_width = width + right + left
    new_height = height + top + bottom

    result = Image.new("RGB", (new_width, new_height), (255, 255, 255))
    result.paste(image, (left, top))
    result.save('/content/nntest/nn{0}'.format(i))
# Out:
# Note3_c9096621340.jpg

# %% [markdown]
# ## Zip results of margin add image

# %%
# !zip -r /content/nntest.zip /content/nntest/
# Out:
#   adding: content/nntest/ (stored 0%)
#   adding: content/nntest/nnc1416761441.jpg (deflated 25%)
#   adding: content/nntest/nnNote10_c10133291341.jpg (deflated 27%)
#   adding: content/nntest/nnNote11_c9774415748.jpg (deflated 25%)
#   adding: content/nntest/nnNote23_c1881721440.jpg (deflated 25%)
#   adding: content/nntest/nnNote10_c4843104749_2.jpg (deflated 20%)
#   adding: content/nntest/nnNote8_c4191011541.jpg (deflated 20%)
#   adding: content/nntest/nnNote10_c10886941441.jpg (deflated 25%)
#   adding: content/nntest/nnNote11_c10143321441.jpg (deflated 27%)
#   adding: content/nntest/nnNote1_c1616821972.jpg (deflated 21%)
#   adding: content/nntest/nnNote22_c8148741242.jpg (deflated 26%)
#   adding: content/nntest/nnc6132311340.jpg (deflated 28%)
#   adding: content/nntest/nnNote11_c9988241440.jpg (deflated 25%)
#   adding: content/nntest/nnNote4_c5905373343_1.jpg (deflated 24%)
#   adding: content/nntest/nnNote11_c2969185452.jpg (deflated 24%)
#   adding: content/nntest/nnNote10_c4769287547.jpg (deflated 22%)
#   adding: content/nntest/nnNote22_
jpg (deflated 24%)
#   adding: content/nntest/nnNote11_c5037081441.jpg (deflated 27%)
#   adding: content/nntest/nnNote10_c3989287547.jpg (deflated 22%)
#   adding: content/nntest/nnNote2_c75712694675_2.jpg (deflated 25%)
#   adding: content/nntest/nnc4496761541.jpg (deflated 22%)
#   adding: content/nntest/nnNote10_c6844402040.jpg (deflated 24%)
#   adding: content/nntest/nnNote10_c10823451340.jpg (deflated 27%)
#   adding: content/nntest/nnNote23_c991552041.jpg (deflated 24%)
#   adding: content/nntest/nnNote23_c75810751438.jpg (deflated 28%)
#   adding: content/nntest/nnc1415231440.jpg (deflated 26%)
#   adding: content/nntest/nnNote7_c9018316449.jpg (deflated 25%)
#   adding: content/nntest/nnNote4_c106414274571_2.jpg (deflated 19%)
#   adding: content/nntest/nnNote11_c6558042140.jpg (deflated 23%)
#   adding: content/nntest/nnNote8_c9816901539.jpg (deflated 20%)
#   adding: content/nntest/nnNote9_c3039651440.jpg (deflated 21%)
#   adding: content/nntest/nnNote11_c4739337447.jpg (deflated 25%)
#   adding: content/nntest/nnNote4_c7173811940.jpg (deflated 16%)
#   adding: content/nntest/nnNote11_c5174431941.jpg (deflated 25%)
#   adding: content/nntest/nnNote22_c44811441440.jpg (deflated 25%)
#   adding: content/nntest/nnNote3_c574911545.jpg (deflated 20%)
#   adding: content/nntest/nnNote2_c40415468357_1.jpg (deflated 22%)
#   adding: content/nntest/nnNote3_c5316671340.jpg (deflated 27%)
#   adding: content/nntest/nnNote11_c4361972142.jpg (deflated 23%)
#   adding: content/nntest/nnNote10_c7487946462_2.jpg (deflated 23%)
#   adding: content/nntest/nnNote3_c19514343147_1.jpg (deflated 20%)
#   adding: content/nntest/nnNote2_c4298571540.jpg (deflated 20%)
#   adding: content/nntest/nnNote4_c43014471440.jpg (deflated 27%)
#   adding: content/nntest/nnNote10_c5547044043.jpg (deflated 22%)
#   adding: content/nntest/nnNote11_c8858191441.jpg (deflated 25%)
#   adding: content/nntest/nnNote3_c2778751341.jpg (deflated 25%)
#   adding: content/nntest/nnNote9_c8788210748.jpg (deflated 25%)
#   adding: content/nntest/nnNote4_c68311421341.jpg (deflated 27%)
#   adding: content/nntest/nnc3182171540.jpg (deflated 21%)
#   adding: content/nntest/nnNote10_c10809233643.jpg (deflated 25%)
#   adding: content/nntest/nnNote3_c83415491340.jpg (deflated 29%)
#   adding: content/nntest/nnNote4_c59814274571_2.jpg (deflated 21%)
#   adding: content/nntest/nnNote8_c4193881541.jpg (deflated 20%)
#   adding: content/nntest/nnNote9_c579952240.jpg (deflated 20%)
#   adding: content/nntest/nnNote2_c23814081340.jpg (deflated 24%)
#   adding: content/nntest/nnNote22_c29210511440.jpg (deflated 27%)
#   adding: content/nntest/nnNote2_c5999534941_2.jpg (deflated 22%)
#   adding: content/nntest/nnNote3_c47012132456.jpg (deflated 20%)
#   adding: content/nntest/nnNote22_c909604746.jpg (deflated 28%)
#   adding: content/nntest/nnNote1_c2919909357.jpg (deflated 25%)
#   adding: content/nntest/nnNote3_c684766455.jpg (deflated 19%)
#   adding: content/nntest/nnNote3_c90912331540.jpg (deflated 20%)
#   adding: content/nntest/nnNote11_c3439341341.jpg (deflated 27%)
#   adding: content/nntest/nnNote3_c32515541341.jpg (deflated 27%)
#   adding: content/nntest/nnNote23_c5731761341.jpg (deflated 28%)
#   adding: content/nntest/nnNote22_c9923471341.jpg (deflated 25%)
#   adding: content/nntest/nnNote4_c43012991441.jpg (deflated 28%)
#   adding: content/nntest/nnNote3_c9516671540.jpg (deflated 20%)
#   adding: content/nntest/nnNote11_c6097043746.jpg (deflated 23%)
#   adding: content/nntest/nnc5183901740.jpg (deflated 24%)
#   adding: content/nntest/nnNote10_c9952241241.jpg (deflated 27%)
#   adding: content/nntest/nnNote22_c7963622041.jpg (deflated 23%)
#   adding: content/nntest/nnNote9_c4516761441.jpg (deflated 21%)
#   adding: content/nntest/nnNote3_c2006621440.jpg (deflated 28%)
#   adding: content/nntest/nnNote23_c55011732042.jpg (deflated 24%)
#   adding: content/nntest/nnNote3_c4772995556_2.jpg (deflated 18%)
#   adding: content/nntest/nnNote11_c10998341439.jpg (deflated 27%)
#   adding: content/nntest/nnNote4_c72712991441.jpg (deflated 26%)
#   adding: content/nntest/nnNote23_c537851441.jpg (deflated 25%)
#   adding: content/nntest/nnNote4_c9225373343.jpg (deflated 23%)
#   adding: content/nntest/nnNote3_c10501816952_1.jpg (deflated 18%)
#   adding: content/nntest/nnNote10_c10978301438.jpg (deflated 30%)
#   adding: content/nntest/nnNote10_c3318051340.jpg (deflated 27%)
#   adding: content/nntest/nnNote3_c35414352151.jpg (deflated 21%)
#   adding: content/nntest/nnNote10_c9517001340.jpg (deflated 28%)
#   adding: content/nntest/nnNote2_c6688525053_1.jpg (deflated 19%)
#   adding: content/nntest/nnNote22_c3131651442.jpg (deflated 25%)
#   adding: content/nntest/nnNote11_c4898181442.jpg (deflated 27%)
#   adding: content/nntest/nnNote23_c108911531448.jpg (deflated 26%)
#   adding: content/nntest/nnNote10_c5383104465.jpg (deflated 20%)
#   adding: content/nntest/nnNote10_c8614216165.jpg (deflated 22%)
#   adding: content/nntest/nnNote3_c7529831341.jpg (deflated 26%)
#   adding: content/nntest/nnNote8_c10773781541.jpg (deflated 20%)
#   adding: content/nntest/nnNote8_c828911341.jpg (deflated 28%)
#   adding: content/nntest/nnNote10_c6837942961.jpg (deflated 23%)
#   adding: content/nntest/nnNote23_c1772572544.jpg (deflated 24%)
#   adding: content/nntest/nnNote4_c67113024755_2.jpg (deflated 22%)
#   adding: content/nntest/nnNote6_c487616071.jpg (deflated 26%)
#   adding: content/nntest/nnNote3_c61914501440.jpg (deflated 21%)
#   adding: content/nntest/nnNote22_c93010711438.jpg (deflated 29%)
#   adding: content/nntest/nnNote23_c658701341.jpg (deflated 25%)
#   adding: content/nntest/nnNote11_c6354531440.jpg (deflated 28%)
#   adding: content/nntest/nnNote9_c10453881341.jpg (deflated 27%)
#   adding: content/nntest/nnNote4_c6809941941.jpg (deflated 25%)
#   adding: content/nntest/nnNote4_c5905373343_2.jpg (deflated 22%)
#   adding: content/nntest/nnNote5_c63665110851.jpg (deflated 21%)
#   adding: content/nntest/nnNote2_c1983904660_3.jpg (deflated 22%)
#   adding: content/nntest/nnNote1_c6652651341.jpg (deflated 24%)
#   adding: content/nntest/nnNote1_c16812083855_1.jpg (deflated 25%)
#   adding: content/nntest/nnc2105231540.jpg (deflated 23%)
#   adding: content/nntest/nnNote3_c6879831341.jpg (deflated 26%)
#   adding: content/nntest/nnNote10_c8408101440.jpg (deflated 27%)
#   adding: content/nntest/nnNote1_c28612064045.jpg (deflated 19%)
#   adding: content/nntest/nnNote11_c10077041340.jpg (deflated 24%)
#   adding: content/nntest/nnNote10_c6113168455.jpg (deflated 19%)
#   adding: content/nntest/nnNote11_c3338091341.jpg (deflated 27%)
#   adding: content/nntest/nnNote23_c1905654244.jpg (deflated 26%)
#   adding: content/nntest/nnNote4_c10049995143_2.jpg (deflated 20%)
#   adding: content/nntest/nnNote3_c100013224365_1.jpg (deflated 25%)
#   adding: content/nntest/nnNote11_c8428035151.jpg (deflated 25%)
#   adding: content/nntest/nnNote4_c89710075043.jpg (deflated 24%)
#   adding: content/nntest/nnNote22_c5731751341.jpg (deflated 27%)
#   adding: content/nntest/nnNote11_c7415481951.jpg (deflated 24%)
#   adding: content/nntest/nnNote11_c6143421441.jpg (deflated 27%)
#   adding: content/nntest/nnNote9_c4513931439.jpg (deflated 21%)
#   adding: content/nntest/nnNote10_c8193451240.jpg (deflated 25%)
#   adding: content/nntest/nnNote2_c71315372339.jpg (deflated 18%)
#   adding: content/nntest/nnNote3_c28813363253_1.jpg (deflated 20%)
#   adding: content/nntest/nnNote23_c7811663445.jpg (deflated 26%)
#   adding: content/nntest/nnNote22_c9541501941.jpg (deflated 23%)
#   adding: content/nntest/nnNote1_c70015385964_1.jpg (deflated 25%)
#   adding: content/nntest/nnNote2_c10874014169_2.jpg (deflated 22%)
#   adding: content/nntest/nnNote4_c89714471340.jpg (deflated 29%)
#   adding: content/nntest/nnNote11_c1449493643.jpg (deflated 22%)
#   adding: content/nntest/nnNote9_c5796662241.jpg (deflated 21%)
#   adding: content/nntest/nnNote1_c10386867071_2.jpg (deflated 23%)
#   adding: content/nntest/nnNote6_c3663876640.jpg (deflated 23%)
#   adding: content/nntest/nnNote22_c50310711438.jpg (deflated 29%)
#   adding: content/nntest/nnNote2_c9519531441.jpg (deflated 26%)
#   adding: content/nntest/nnNote4_c89712991341.jpg (deflated 27%)
#   adding: content/nntest/nnNote22_c10233672041.jpg (deflated 22%)
#   adding: content/nntest/nnNote1_c59013373050.jpg (deflated 22%)
#   adding: content/nntest/nnNote3_c2769931440.jpg (deflated 26%)
#   adding: content/nntest/nnNote2_c81915353668_1.jpg (deflated 19%)
#   adding: content/nntest/nnNote11_c1413132046.jpg (deflated 24%)
#   adding: content/nntest/nnNote3_c68815318164.jpg (deflated 27%)
#   adding: content/nntest/nnNote22_c505751341.jpg (deflated 25%)
#   adding: content/nntest/nnNote3_c40013363253_1.jpg (deflated 23%)
#   adding: content/nntest/nnNote10_c2994551241.jpg (deflated 26%)
#   adding: content/nntest/nnNote2_c23815511341.jpg (deflated 24%)
#   adding: content/nntest/nnNote23_c504751341.jpg (deflated 27%)
#   adding: content/nntest/nnNote10_c2502042341.jpg (deflated 23%)
#   adding: content/nntest/nnNote2_c4342955045_1.jpg (deflated 25%)
#   adding: content/nntest/nnNote2_c5011704270_1.jpg (deflated 22%)
#   adding: content/nntest/nnNote8_c10336751341.jpg (deflated 27%)
#   adding: content/nntest/nnNote10_c2978141442.jpg (deflated 25%)
#   adding: content/nntest/nnNote3_c3192111940.jpg (deflated 24%)
#   adding: content/nntest/nnNote3_c3224012953_2.jpg (deflated 24%)
#   adding: content/nntest/nnNote4_c1542325664_1.jpg (deflated 19%)
#   adding: content/nntest/nnNote22_c9308741342.jpg (deflated 27%)
#   adding: content/nntest/nnNote10_c1406694750_1.jpg (deflated 21%)
#   adding: content/nntest/nnNote10_c1404402040.jpg (deflated 22%)
#   adding: content/nntest/nnNote1_c16913393643_2.jpg (deflated 23%)
#   adding: content/nntest/nnNote3_c68115491341.jpg (deflated 29%)
#   adding: content/nntest/nnNote3_c27112181341.jpg (deflated 28%)
#   adding: content/nntest/nnNote11_c7798141540.jpg (deflated 20%)
#   adding: content/nntest/nnNote22_c17212861347.jpg (deflated 25%)
#   adding: content/nntest/nnNote10_c5687942142.jpg (deflated 24%)
#   adding: content/nntest/nnNote22_c98311483776.jpg (deflated 20%)
#   adding: content/nntest/nnNote22_c61811481342.jpg (deflated 26%)
#   adding: content/nntest/nnNote2_c10299537068_1.jpg (deflated 23%)
#   adding: content/nntest/nnNote11_c9447936147.jpg (deflated 23%)
#   adding: content/nntest/nnNote9_c4519651440.jpg (deflated 21%)
#   adding: content/nntest/nnNote3_c40013363253_2.jpg (deflated 22%)
#   adding: content/nntest/nnNote9_c5763982541.jpg (deflated 18%)
#   adding: content/nntest/nnNote22_c98310711438.jpg (deflated 28%)
#   adding: content/nntest/nnNote1_c36212034862_2.jpg (deflated 19%)
#   adding: content/nntest/nnNote3_c1562959859_2.jpg (deflated 22%)
#   adding: content/nntest/nnNote1_c5001804345_1.jpg (deflated 25%)
#   adding: content/nntest/nnNote2_c4314015373_2.jpg (deflated 18%)
#   adding: content/nntest/nnNote5_c8259417343.jpg (deflated 18%)
#   adding: content/nntest/nnNote11_c1404422242.jpg (deflated 22%)
#   adding: content/nntest/nnNote3_c79314601439.jpg (deflated 21%)
#   adding: content/nntest/nnNote11_c9339137847.jpg (deflated 22%)
#   adding: content/nntest/nnNote23_c9943481441.jpg (deflated 26%)
#   adding: content/nntest/nnNote1_c7132651341.jpg (deflated 24%)
#   adding: content/nntest/nnNote2_c10299537068_2.jpg (deflated 22%)
#   adding: content/nntest/nnNote23_c44410641441.jpg (deflated 29%)
#   adding: content/nntest/nnNote10_c2403104765.jpg (deflated 23%)
#   adding: content/nntest/nnNote7_c1653851440.jpg (deflated 26%)
#   adding: content/nntest/nnNote22_c1914791341.jpg (deflated 27%)
#   adding: content/nntest/nnNote1_c30315694746.jpg (deflated 19%)
#   adding: content/nntest/nnNote10_c6162101340.jpg (deflated 27%)
#   adding: content/nntest/nnNote3_c41914423148.jpg (deflated 19%)
#   adding: content/nntest/nnNote3_c90914601339.jpg (deflated 27%)
#   adding: content/nntest/nnNote3_c4772995556_1.jpg (deflated 23%)
#   adding: content/nntest/nnNote23_c92711491340.jpg (deflated 25%)
#   adding: content/nntest/nnNote2_c2537167179_1.jpg (deflated 22%)
#   adding: content/nntest/nnNote23_c1919681442.jpg (deflated 27%)
#   adding: content/nntest/nnNote11_c7557081441.jpg (deflated 27%)
#   adding: content/nntest/nnNote10_c6344501340.jpg (deflated 27%)
#   adding: content/nntest/nnNote3_c94514601439.jpg (deflated 21%)
#   adding: content/nntest/nnNote11_c8497083944.jpg (deflated 23%)
#   adding: content/nntest/nnNote23_c1906581341.jpg (deflated 27%)
#   adding: content/nntest/nnNote10_c2055595260_1.jpg (deflated 23%)
#   adding: content/nntest/nnNote5_c4879362040.jpg (deflated 24%)
#   adding: content/nntest/nnNote23_c80011592450.jpg (deflated 18%)
#   adding: content/nntest/nnNote5_c2706611541.jpg (deflated 19%)
#   adding: content/nntest/nnNote8_c9813981340.jpg (deflated 27%)
#   adding: content/nntest/nnNote2_c4902945354_1.jpg (deflated 22%)
#   adding: content/nntest/nnNote23_c4553532341.jpg (deflated 22%)
#   adding: content/nntest/nnNote3_c538861441.jpg (deflated 27%)
#   adding: content/nntest/nnNote11_c1448193543.jpg (deflated 20%)
#   adding: content/nntest/nnNote22_c11118901946.jpg (deflated 26%)
#   adding: content/nntest/nnc1732171440.jpg (deflated 24%)
#   adding: content/nntest/nnNote11_c10099192141.jpg (deflated 23%)
#   adding: content/nntest/nnNote1_c98315591540.jpg (deflated 20%)
#   adding: content/nntest/nnNote3_c21315541341.jpg (deflated 27%)
#   adding: content/nntest/nnNote3_c6082945561_2.jpg (deflated 19%)
#   adding: content/nntest/nnNote4_c82014521438.jpg (deflated 29%)
#   adding: content/nntest/nnNote11_c5684681341.jpg (deflated 27%)
#   adding: content/nntest/nnNote8_c3166901339.jpg (deflated 27%)
#   adding: content/nntest/nnNote2_c8649681439.jpg (deflated 24%)
#   adding: content/nntest/nnNote1_c1649084940.jpg (deflated 18%)
#   adding: content/nntest/nnNote22_c76010711438.jpg (deflated 28%)
#   adding: content/nntest/nnNote11_c3994681341.jpg (deflated 27%)
#   adding: content/nntest/nnNote4_c53910075043_1.jpg (deflated 22%)
#   adding: content/nntest/nnNote4_c89711505066.jpg (deflated 24%)
#   adding: content/nntest/nnNote11_c8203481341.jpg (deflated 25%)
#   adding: content/nntest/nnNote4_c8179894671.jpg (deflated 18%)
#   adding: content/nntest/nnNote2_c2778621539.jpg (deflated 20%)
#   adding: content/nntest/nnNote2_c81915353668_2.jpg (deflated 25%)
#   adding: content/nntest/nnNote10_c7196838862.jpg (deflated 21%)
#   adding: content/nntest/nnNote10_c7889144145_1.jpg (deflated 27%)
#   adding: content/nntest/nnNote4_c59810041341.jpg (deflated 25%)
#   adding: content/nntest/nnNote3_c1397654342.jpg (deflated 24%)
#   adding: content/nntest/nnNote11_c7929194145.jpg (deflated 25%)
#   adding: content/nntest/nnNote22_c4211693342.jpg (deflated 23%)
#   adding: content/nntest/nnc6048501740.jpg (deflated 22%)
#   adding: content/nntest/nnNote3_c5979891340.jpg (deflated 26%)
#   adding: content/nntest/nnNote22_c5051811338.jpg (deflated 27%)
#   adding: content/nntest/nnc6748431442.jpg (deflated 25%)
#   adding: content/nntest/nnNote11_c5817905060.jpg (deflated 27%)
#   adding: content/nntest/nnNote3_c608811346.jpg (deflated 27%)
#   adding: content/nntest/nnNote11_c3979337447.jpg (deflated 26%)
#   adding: content/nntest/nnNote10_c3595594747.jpg (deflated 20%)
#   adding: content/nntest/nnNote10_c5322152341.jpg (deflated 23%)
#   adding: content/nntest/nnNote3_c30714343147.jpg (deflated 20%)
#   adding: content/nntest/nnNote3_c105515641340.jpg (deflated 26%)
#   adding: content/nntest/nnNote10_c4947975058.jpg (deflated 24%)
#   adding: content/nntest/nnNote11_c6665582041.jpg (deflated 23%)
#   adding: content/nntest/nnNote10_c10457041441.jpg (deflated 27%)
#   adding: content/nntest/nnNote1_c10386867071_3.jpg (deflated 22%)
#   adding: content/nntest/nnNote3_c5382906355_1.jpg (deflated 24%)
#   adding: content/nntest/nnNote23_c5733581441.jpg (deflated 27%)
#   adding: content/nntest/nnNote3_c51112118152.jpg (deflated 23%)
#   adding: content/nntest/nnNote11_c9295535650_1.jpg (deflated 18%)
#   adding: content/nntest/nnNote4_c7005373343_1.jpg (deflated 24%)
#   adding: content/nntest/nnNote1_c20810071440.jpg (deflated 25%)
#   adding: content/nntest/nnNote9_c9883884241.jpg (deflated 20%)
#   adding: content/nntest/nnNote4_c5395342340.jpg (deflated 19%)
#   adding: content/nntest/nnNote23_c1904811341.jpg (deflated 27%)
#   adding: content/nntest/nnNote2_c106315401441.jpg (deflated 21%)
#   adding: content/nntest/nnNote11_c10839273643.jpg (deflated 23%)
#   adding: content/nntest/nnNote3_c69813124371_1.jpg (deflated 23%)
#   adding: content/nntest/nnNote23_c58611631341.jpg (deflated 26%)
#   adding: content/nntest/nnNote8_c87866116264.jpg (deflated 21%)
#   adding: content/nntest/nnNote4_c33011521341.jpg (deflated 27%)
#   adding: content/nntest/nnNote11_c10615535370_1.jpg (deflated 24%)
#   adding: content/nntest/nnNote4_c67113024755_1.jpg (deflated 25%)
#   adding: content/nntest/nnNote2_c7386222340.jpg (deflated 16%)
#   adding: content/nntest/nnNote10_c14310548651.jpg (deflated 25%)
#   adding: content/nntest/nnNote10_c5775592041.jpg (deflated 24%)
#   adding: content/nntest/nnNote23_c61511531442.jpg (deflated 26%)
#   adding: content/nntest/nnNote8_c978862041.jpg (deflated 24%)
#   adding: content/nntest/nnNote22_c989551941.jpg (deflated 25%)
#   adding: content/nntest/nnNote11_c3484681440.jpg (deflated 27%)
#   adding: content/nntest/nnNote2_c104212991341.jpg (deflated 27%)
#   adding: content/nntest/nnNote3_c3224012953_1.jpg (deflated 23%)
#   adding: content/nntest/nnNote23_c959651441.jpg (deflated 27%)
#   adding: content/nntest/nnNote2_c108512733367_2.jpg (deflated 24%)
#   adding: content/nntest/nnNote23_c9941811439.jpg (deflated 27%)
#   adding: content/nntest/nnNote2_c5998422241.jpg (deflated 20%)
#   adding: content/nntest/nnNote2_c8234013553_1.jpg (deflated 23%)
#   adding: content/nntest/nnNote11_c10408241340.jpg (deflated 25%)
#   adding: content/nntest/nnNote23_c81010751438.jpg (deflated 28%)
#   adding: content/nntest/nnNote3_c9098901339.jpg (deflated 29%)
#   adding: content/nntest/nnNote3_c19514343147_2.jpg (deflated 25%)
#   adding: content/nntest/nnNote3_c7553964668.jpg (deflated 26%)
#   adding: content/nntest/nnNote3_c38312181341.jpg (deflated 27%)
#   adding: content/nntest/nnNote3_c4419881440.jpg (deflated 27%)
#   adding: content/nntest/nnNote3_c6866671440.jpg (deflated 27%)
#   adding: content/nntest/nnNote6_c10306566340.jpg (deflated 21%)
#   adding: content/nntest/nnNote22_c1026781348.jpg (deflated 28%)
#   adding: content/nntest/nnNote1_c98013612646.jpg (deflated 19%)
#   adding: content/nntest/nnNote4_c9785289372_2.jpg (deflated 25%)
#   adding: content/nntest/nnNote1_c70015385964_3.jpg (deflated 22%)
#   adding: content/nntest/nnNote3_c75612331440.jpg (deflated 21%)
#   adding: content/nntest/nnNote2_c6579616155_2.jpg (deflated 22%)
#   adding: content/nntest/nnNote10_c7778101440.jpg (deflated 22%)
#   adding: content/nntest/nnNote2_c8753001541.jpg (deflated 20%)
#   adding: content/nntest/nnNote3_c2008588664.jpg (deflated 25%)
#   adding: content/nntest/nnNote4_c27111405064.jpg (deflated 20%)
#   adding: content/nntest/nnNote10_c8477995057.jpg (deflated 22%)
#   adding: content/nntest/nnNote3_c8486521440.jpg (deflated 26%)
#   adding: content/nntest/nnNote22_c690751341.jpg (deflated 26%)
#   adding: content/nntest/nnNote2_c434805054_2.jpg (deflated 24%)
#   adding: content/nntest/nnNote8_c6566791541.jpg (deflated 20%)
#   adding: content/nntest/nnNote3_c2347765654.jpg (deflated 25%)
#   adding: content/nntest/nnNote3_c28813363253_2.jpg (deflated 22%)
#   adding: content/nntest/nnNote10_c3666692046.jpg (deflated 24%)
#   adding: content/nntest/nnNote11_c10778281642.jpg (deflated 20%)
#   adding: content/nntest/nnNote8_c16339316651.jpg (deflated 22%)
#   adding: content/nntest/nnNote7_c90165415543.jpg (deflated 23%)
#   adding: content/nntest/nnNote2_c31714085340_2.jpg (deflated 22%)
#   adding: content/nntest/nnNote3_c3077761340.jpg (deflated 24%)
#   adding: content/nntest/nnNote8_c653812041.jpg (deflated 25%)
#   adding: content/nntest/nnNote10_c8813291441.jpg (deflated 27%)
#   adding: content/nntest/nnNote22_c5733561441.jpg (deflated 25%)
#   adding: content/nntest/nnNote10_c7591829063.jpg (deflated 18%)
#   adding: content/nntest/nnNote23_c8012571441.jpg (deflated 25%)
#   adding: content/nntest/nnNote23_c910604746.jpg (deflated 28%)
#   adding: content/nntest/nnNote10_c3283189848.jpg (deflated 22%)
#   adding: content/nntest/nnNote11_c5577084044.jpg (deflated 23%)
#   adding: content/nntest/nnNote2_c75711284979_2.jpg (deflated 23%)
#   adding: content/nntest/nnNote11_c2688042040.jpg (deflated 24%)
#   adding: content/nntest/nnNote6_c969762558.jpg (deflated 26%)
#   adding: content/nntest/nnNote10_c4654501340.jpg (deflated 29%)
#   adding: content/nntest/nnNote2_c4297213852_2.jpg (deflated 19%)
#   adding: content/nntest/nnNote23_c690751441.jpg (deflated 26%)
#   adding: content/nntest/nnNote22_c76011481442.jpg (deflated 25%)
#   adding: content/nntest/nnNote11_c6952022041.jpg (deflated 23%)
#   adding: content/nntest/nnNote11_c4664531440.jpg (deflated 28%)
#   adding: content/nntest/nnNote4_c2055374560_1.jpg (deflated 24%)
#   adding: content/nntest/nnc6046761441.jpg (deflated 25%)
#   adding: content/nntest/nnNote10_c1909403639.jpg (deflated 23%)
#   adding: content/nntest/nnNote22_c190751241.jpg (deflated 27%)
#   adding: content/nntest/nnNote3_c1544014666_2.jpg (deflated 25%)
#   adding: content/nntest/nnNote3_c10802975158.jpg (deflated 25%)
#   adding: content/nntest/nnNote23_c3423642640.jpg (deflated 21%)
#   adding: content/nntest/nnNote1_c2856924548_1.jpg (deflated 26%)
#   adding: content/nntest/nnNote1_c16913393643_1.jpg (deflated 23%)
#   adding: content/nntest/nnNote10_c8554591441.jpg (deflated 27%)
#   adding: content/nntest/nnNote22_c103710711438.jpg (deflated 29%)
#   adding: content/nntest/nnNote11_c7008191341.jpg (deflated 25%)
#   adding: content/nntest/nnNote10_c2055595260_2.jpg (deflated 22%)
#   adding: content/nntest/nnNote3_c5329931341.jpg (deflated 26%)
#   adding: content/nntest/nnNote11_c8018191341.jpg (deflated 27%)
#   adding: content/nntest/nnNote4_c2719995043.jpg (deflated 19%)
#   adding: content/nntest/nnNote11_c2278041940.jpg (deflated 25%)
#   adding: content/nntest/nnNote3_c6082945561_1.jpg (deflated 24%)
#   adding: content/nntest/nnNote10_c5154401940.jpg (deflated 23%)
#   adding: content/nntest/nnNote8_c5536646854.jpg (deflated 24%)
#   adding: content/nntest/nnNote22_c39410561441.jpg (deflated 25%)
#   adding: content/nntest/nnNote2_c40415468357_3.jpg (deflated 26%)
#   adding: content/nntest/nnNote23_c3121661341.jpg (deflated 27%)
#   adding: content/nntest/nnNote10_c7473451440.jpg (deflated 28%)
#   adding: content/nntest/nnNote1_c70015385964_2.jpg (deflated 21%)
#   adding: content/nntest/nnNote4_c106414274571_1.jpg (deflated 17%)
#   adding: content/nntest/nnNote7_c10503612341.jpg (deflated 19%)
#   adding: content/nntest/nnNote23_c6459841338.jpg (deflated 30%)
#   adding: content/nntest/nnNote7_c7499458868.jpg (deflated 22%)
#   adding: content/nntest/nnNote4_c7615342240.jpg (deflated 19%)
#   adding: content/nntest/nnNote3_c21313313156.jpg (deflated 23%)
#   adding: content/nntest/nnNote10_c7127001440.jpg (deflated 25%)
#   adding: content/nntest/nnNote10_c1926804046.jpg (deflated 20%)
#   adding: content/nntest/nnNote3_c674811346.jpg (deflated 26%)
#   adding: content/nntest/nnNote4_c76412784759_2.jpg (deflated 24%)
#   adding: content/nntest/nnNote10_c9955594747.jpg (deflated 20%)
#   adding: content/nntest/nnNote3_c274822745.jpg (deflated 20%)
#   adding: content/nntest/nnNote3_c5382906355_2.jpg (deflated 19%)
#   adding: content/nntest/nnNote4_c8145274867.jpg (deflated 23%)
#   adding: content/nntest/nnNote3_c10501816952.jpg (deflated 18%)
#   adding: content/nntest/nnNote11_c14410598751.jpg (deflated 25%)
#   adding: content/nntest/nnc3658431342.jpg (deflated 28%)
#   adding: content/nntest/nnNote3_c17613363353_2.jpg (deflated 23%)
#   adding: content/nntest/nnNote2_c434805054_1.jpg (deflated 22%)
#   adding: content/nntest/nnNote11_c2998191441.jpg (deflated 24%)
#   adding: content/nntest/nnNote23_c188751441.jpg (deflated 27%)
#   adding: content/nntest/nnNote22_c1916561341.jpg (deflated 25%)
#   adding: content/nntest/nnNote11_c8833321441.jpg (deflated 27%)
#   adding: content/nntest/nnNote3_c5328707846_2.jpg (deflated 23%)
#   adding: content/nntest/nnNote10_c9275505649_2.jpg (deflated 22%)
#   adding: content/nntest/nnNote3_c4291952746.jpg (deflated 21%)
#   adding: content/nntest/nnNote10_c4283204539.jpg (deflated 19%)
#   adding: content/nntest/nnNote22_c1863672141.jpg (deflated 23%)
#   adding: content/nntest/nnNote4_c10049995143_1.jpg (deflated 18%)
#   adding: content/nntest/nnNote23_c1853682641.jpg (deflated 22%)
#   adding: content/nntest/nnNote10_c9754386267.jpg (deflated 25%)
#   adding: content/nntest/nnNote11_c6859293946.jpg (deflated 23%)
#   adding: content/nntest/nnNote3_c93312151554.jpg (deflated 23%)
#   adding: content/nntest/nnNote1_c102915652552.jpg (deflated 17%)
#   adding: content/nntest/nnNote10_c4843104749_1.jpg (deflated 21%)
#   adding: content/nntest/nnNote22_c10378741342.jpg (deflated 26%)
#   adding: content/nntest/nnNote7_c8973872046.jpg (deflated 23%)
#   adding: content/nntest/nnNote3_c5328707846_1.jpg (deflated 20%)
#   adding: content/nntest/nnNote3_c38315541341.jpg (deflated 27%)
#   adding: content/nntest/nnNote4_c33012744266.jpg (deflated 25%)
#   adding: content/nntest/nnNote11_c4216732046.jpg (deflated 23%)
#   adding: content/nntest/nnNote4_c6445342340.jpg (deflated 20%)
#   adding: content/nntest/nnNote4_c49011671339.jpg (deflated 27%)
#   adding: content/nntest/nnNote3_c27115491340.jpg (deflated 28%)
#   adding: content/nntest/nnc2392171340.jpg (deflated 24%)
#   adding: content/nntest/nnNote11_c2532071341.jpg (deflated 27%)
#   adding: content/nntest/nnNote22_c7651651242.jpg (deflated 24%)
#   adding: content/nntest/nnNote3_c1058537766.jpg (deflated 26%)
#   adding: content/nntest/nnNote4_c7519991441.jpg (deflated 27%)
#   adding: content/nntest/nnNote3_c1847653045.jpg (deflated 24%)
#   adding: content/nntest/nnNote2_c5011704270_2.jpg (deflated 22%)
#   adding: content/nntest/nnNote11_c10487081341.jpg (deflated 27%)
#   adding: content/nntest/nnNote2_c3317269047_2.jpg (deflated 24%)
#   adding: content/nntest/nnc6782311440.jpg (deflated 25%)
#   adding: content/nntest/nnNote23_c10281711441.jpg (deflated 27%)
#   adding: content/nntest/nnNote3_c8499791340.jpg (deflated 25%)
#   adding: content/nntest/nnNote22_c10948701340.jpg (deflated 26%)
#   adding: content/nntest/nnNote11_c1878143246.jpg (deflated 23%)
#   adding: content/nntest/nnNote10_c6655541942.jpg (deflated 23%)
#   adding: content/nntest/nnNote3_c69813124371.jpg (deflated 24%)
#   adding: content/nntest/nnNote3_c7528901338.jpg (deflated 29%)
#   adding: content/nntest/nnNote3_c3076721339.jpg (deflated 29%)
#   adding: content/nntest/nnNote10_c10099142141.jpg (deflated 23%)
#   adding: content/nntest/nnNote10_c1405594747_2.jpg (deflated 21%)
#   adding: content/nntest/nnNote2_c7979714143_1.jpg (deflated 23%)
#   adding: content/nntest/nnNote9_c1619702641.jpg (deflated 20%)
#   adding: content/nntest/nnNote11_c9523481341.jpg (deflated 27%)
#   adding: content/nntest/nnNote1_c39513322340.jpg (deflated 19%)
#   adding: content/nntest/nnNote3_c21312073452_2.jpg (deflated 25%)
#   adding: content/nntest/nnNote22_c10261701341.jpg (deflated 27%)
#   adding: content/nntest/nnNote3_c9213041341.jpg (deflated 28%)
#   adding: content/nntest/nnNote11_c3076832141.jpg (deflated 22%)
#   adding: content/nntest/nnNote11_c6864431941.jpg (deflated 25%)
#   adding: content/nntest/nnc4485231440.jpg (deflated 25%)
#   adding: content/nntest/nnc6035421641.jpg (deflated 22%)
#   adding: content/nntest/nnNote23_c7651661441.jpg (deflated 25%)
#   adding: content/nntest/nnNote3_c2297612746.jpg (deflated 21%)
#   adding: content/nntest/nnNote3_c84115318164.jpg (deflated 29%)
#   adding: content/nntest/nnNote10_c3974641441.jpg (deflated 25%)
#   adding: content/nntest/nnNote2_c7269635558_1.jpg (deflated 24%)
#   adding: content/nntest/nnNote4_c4054061541.jpg (deflated 20%)
#   adding: content/nntest/nnNote3_c9976521340.jpg (deflated 29%)
#   adding: content/nntest/nnNote2_c10874014169_1.jpg (deflated 19%)
#   adding: content/nntest/nnNote9_c8783881340.jpg (deflated 27%)
#   adding: content/nntest/nnNote4_c7005373343_2.jpg (deflated 22%)
#   adding: content/nntest/nnNote10_c4341952141.jpg (deflated 23%)
#   adding: content/nntest/nnNote3_c21312073452_1.jpg (deflated 25%)
#   adding: content/nntest/nnNote22_c3291663244.jpg (deflated 23%)
#   adding: content/nntest/nnNote23_c64510751438.jpg (deflated 28%)
#   adding: content/nntest/nnNote2_c66915313672_1.jpg (deflated 23%)
#   adding: content/nntest/nnNote2_c10408525939_1.jpg (deflated 21%)
#   adding: content/nntest/nnNote22_c5568741342.jpg (deflated 27%)
#   adding: content/nntest/nnNote1_c9668081441.jpg (deflated 20%)
#   adding: content/nntest/nnNote4_c2565391441.jpg (deflated 25%)
#   adding: content/nntest/nnNote23_c8739781441.jpg (deflated 26%)
#   adding: content/nntest/nnNote11_c7216878962_1.jpg (deflated 29%)
#   adding: content/nntest/nnNote11_c8054272052.jpg (deflated 21%)
#   adding: content/nntest/nnc1418291441.jpg (deflated 26%)
#   adding: content/nntest/nnNote4_c95610041341.jpg (deflated 25%)
#   adding: content/nntest/nnNote4_c2162481441.jpg (deflated 28%)
